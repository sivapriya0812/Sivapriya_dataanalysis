# %% [markdown]
# Pandas:
# *   Used for data manipulation(Data cleaning,Organizing data)
# *   Creates dataframes from excel,csv,txts,DBs
# *   Dataframe(rows and columns readable by python)
# *   Data cleaning by dropping or replacing with mean
# *   Visualize the data

# %%
import pandas as pd

# %%
names=["priya","samhitha","mokshitha","rishika"]
index=[34,40,32,38]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 34        priya
# 40     samhitha
# 32    mokshitha
# 38      rishika
# dtype: object

# %% [markdown]
# Importing Files
# *   For csv and txt:read_csv
# *   For excel:read_excel

# %%
#CSV file
df=pd.read_csv("/content/LA_County_COVID_Cases_20240121.csv")

# %%
df.head(10)
# Out:
#         county       state  fips                    date        Lat  \
# 0  Los Angeles  California  6037  08/27/2021 12:00:00 AM  34.308284
# 1  Los Angeles  California  6037  08/28/2021 12:00:00 AM  34.308284
# 2  Los Angeles  California  6037  08/30/2021 12:00:00 AM  34.308284
# 3  Los Angeles  California  6037  08/31/2021 12:00:00 AM  34.308284
# 4  Los Angeles  California  6037  09/01/2021 12:00:00 AM  34.308284
# 5  Los Angeles  California  6037  09/02/2021 12:00:00 AM  34.308284
# 6  Los Angeles  California  6037  09/03/2021 12:00:00 AM  34.308284
# 7  Los Angeles  California  6037  09/04/2021 12:00:00 AM  34.308284
# 8  Los Angeles  California  6037  09/05/2021 12:00:00 AM  34.308284
# 9  Los Angeles  California  6037  09/06/2021 12:00:00 AM  34.308284
#
#           Lon    cases  deaths  people_tested  state_cases  state_deaths  \
# 0 -118.228241  1407317   25284            NaN      4360789         65873
# ...

# %%
#Text file
dft=pd.read_csv("/content/grades.txt",sep=" ")

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
#EXCEL file
dfe=pd.read_excel("/content/diabetes.xlsx")
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df=pd.read_csv("/content/apple_quality.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df=pd.read_csv("/content/LA_County_COVID_Cases_20240121.csv")
print(df.shape)     #get the number of rows and columns
print(df.shape[0])  #get the number of rows only
print(df.shape[1])  #get the number of columns only
# Out:
# (30489, 15)
# 30489
# 15

# %% [markdown]
# Accessing Data:
# *  loc-accepts column names and index
# * iloc-accepts only index

# %%
print(dft.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade'], dtype='object')

# %%
print(dft[2:5])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5,"Names"])  #rows of specified columns
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5])  #rows of specified columns
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.iloc[2:5, :3]) #iloc[row range, column range] =>index
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum() #to view how many nulls we have per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum() #to view total nulls
# Out:
# 4

# %%
dfn.dropna() #dropping all the rows with all nulls
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc=dfn.dropna() #to save the changes we have to save in other file

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn #doesn't reflect the changes
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5) #replace the null values with 5
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# cleaning with mean

# %%
m=dfn['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
dfc2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=dfc2.drop_duplicates() #removes the duplicates
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Columns

# %%
dfc3=dfn.rename(columns={ "Initials":"Good name"})  #df.rename(columns={old:new})
dfc3
# Out:
#      Names Good name  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe         K   9.8  10.0   9.9    A+       1
# 1   Rajesh         M   8.9   9.1   9.3     A       1
# 2   Kissan         V   9.9   9.8  10.0     A       0
# 3     Mary         N   7.7   8.0   NaN     B       0
# 4     Jeen         K   9.8   9.1   9.9    A+       1
# 5      Raj         M   8.9   9.1   9.3     A       1
# 6   Hassan         V   9.9   9.0   9.2     A       1
# 7     Mari         N   7.7   8.0   7.1     B       1
# 8     Jess         K   NaN   9.1   9.9    A+       1
# 9   Rajini         M   NaN   9.1   9.3     A       0
# 10   Kiran         V   NaN   9.3   9.2     A       0
# 11    Maya         N   7.7   8.0   7.1     B       0
# 12   Jolin         K   9.8   9.1   9.9    A+       1
# 13  Rajesh         M   8.9   9.1   9.3     A       1
# 14    Riya         M   9.3   9.9  10.0     A       1
# 15    Sana         V   9.9   9.3   9.2     A       0
# 16    Mark         N   7.7   8.0   7.0     B       0

# %%
 dfc2.rename(columns={ "Initials":"Good name"},inplace=True)

# %%
dfc2.head()
# Out:
#     Names Good name  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe         K   9.8  10.0   9.9    A+       1
# 1  Rajesh         M   8.9   9.1   9.3     A       1
# 2  Kissan         V   9.9   9.8  10.0     A       0
# 3    Mary         N   7.7   8.0   9.1     B       0
# 4    Jeen         K   9.8   9.1   9.9    A+       1

# %% [markdown]
# *   copy
# *   view

# %%
dfc2['avg_score']=(dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3   #df["newcol"]=values
dfc2.head()
# Out:
#     Names Good name  SEM1  SEM2  SEM3 Grade  Placed  avg_score
# 0     Joe         K   9.8  10.0   9.9    A+       1   9.900000
# 1  Rajesh         M   8.9   9.1   9.3     A       1   9.100000
# 2  Kissan         V   9.9   9.8  10.0     A       0   9.900000
# 3    Mary         N   7.7   8.0   9.1     B       0   8.266667
# 4    Jeen         K   9.8   9.1   9.9    A+       1   9.600000

# %% [markdown]
# Plotting with pandas

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Placed"
)

# %% [markdown]
# * Load diabeties.csvcreate a relplot,with age in X-axis and class as columns

# %%
dfs=pd.read_csv("/content/diabetcsv.csv")
dfs
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dfs['Index']=(range(0,768))
dfs
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      0
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      1
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      2
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      3
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      4
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    763
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    764
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    765
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    766
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    767
#
# [768 rows x 10 columns]

# %%
dfs.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    763
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    764
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    765
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    766
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    767

# %%
dfs=pd.read_csv("/content/diabetcsv.csv")
dfs['Index']=(range(0,768))
sns.relplot(
    data=dfs,
    x="Index",y="age",col="class"
)

# %% [markdown]
# Inbuilt datasets in seaborn
# * Tips
# * dowjones
# * fmri
# * Dots
# * healthexp
# => To load dataset use:
#     * load_dataset("dataset_name")

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pl=sns.lineplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker")
#hue is creating difference based on column via colours

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day")

# %% [markdown]
# hue->different color for diff category
# style->different color for diff marker

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time",style="size",palette="colorblind")

# %% [markdown]
#  color palette:
# ->pastel
# ->bright(as default)
# ->dark
# ->muted
# ->colorblind
# ->deep

# %%
dowjones=sns.load_dataset("dowjones")
dowjones
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=dowjones,x="Date",y="Price",kind="line",color='m')
# Out:
# <ipython-input-135-b3b52ce406c2>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(data=dowjones,x="Date",y="Price",kind="line",color='m',palette="pastel")

# %%
fmri=sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=fmri,x="timepoint",y="signal",kind="line",color='c')

# %%
sns.relplot(data=fmri,x="region",y="timepoint",color='orange',kind="line")

# %%
sns.catplot(data=tips,x="total_bill",y="day",color="pink")

# %%
sns.catplot(data=tips,x="time",y="total_bill",kind="violin",hue="smoker")

# %% [markdown]
# * plot the points
# * fit the line
# * select the line with least difference(linear fit)
# *  implot to create a function

# %%
sns.lmplot(x='size',y='tip',data=tips);
